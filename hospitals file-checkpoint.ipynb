# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from pylab import rcParams

# %%
# upload and read my csv file
df = pd.read_csv(r'C:\Users\Rahul Miglani\Health.csv')
df
# look at data for types of values and more information to see if there is any mistakes or clean up that has to be done 
df.dtypes
df.describe()
df.info()
df.shape
df.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3756 entries, 0 to 3755
# Data columns (total 8 columns):
# Region          3756 non-null object
# District        3756 non-null object
# FacilityName    3756 non-null object
# Type            3756 non-null object
# Town            3603 non-null object
# Ownership       3756 non-null object
# Latitude        3732 non-null float64
# Longitude       3732 non-null float64
# dtypes: float64(2), object(6)
# memory usage: 234.8+ KB
# Index(['Region', 'District', 'FacilityName', 'Type', 'Town', 'Ownership',
#        'Latitude', 'Longitude'],
#       dtype='object')

# %%
#here I used rc params to change my scatter plot so I can actually see what is going on in there
plt.rcParams['figure.figsize'] = 15, 10 
plt.rcParams['font.size'] = 12.0 
plt.rcParams['text.color'] = 'r'
plt.scatter(x = df['Region'], y = df['Type'])
plt.show()

# %%
#The graph above is a scatter plot. It represents the type of clinic in each district

# %%
plt.rcParams['figure.figsize'] = 30, 10
plt.rcParams['font.size'] = 20.0 
x = df['Ownership']
# plot with no marker
plt.scatter(x , y=df.Region)
#plt.show()

# %%
# The plot above represents ownerships of Hospitals in each district.

# %%
df1 = df.drop(['Latitude', 'Longitude'], axis=1)
df1.head(20)
# Out:
#      Region                     District                   FacilityName  \
# 0   Ashanti                Offinso North              A.M.E Zion Clinic
# 1   Ashanti             Bekwai Municipal              Abenkyiman Clinic
# 2   Ashanti                 Adansi North           Aboabo Health Centre
# 3   Ashanti                Afigya-Kwabre        Aboabogya Health Centre
# 4   Ashanti                       Kwabre           Aboaso Health Centre
# 5   Ashanti                Offinso North         Aboffour Health Centre
# 6   Ashanti             Atwima-Nwabiagya         Abuakwa Maternity Home
# 7   Ashanti              Atwima-Kwanwoma       Aburaso Methodist clinic
# 8   Ashanti       Ejisu-Juaben Municipal          Achiase Health Centre
# 9   Ashanti            Mampong Municipal          Adidwan Health Centre
# 10  Ashanti                 Amansie West                  Adimposo CHPS
# 11  Ashanti  Asante-Akim North Municipal                  Adom Hospital
# ...

# %%
# Here I am looking at if my data has missing values 
missing = df1.isnull().sum().sort_values(ascending=False)

# %%
missing
# Out:
# Town            153
# Ownership         0
# Type              0
# FacilityName      0
# District          0
# Region            0
# dtype: int64

# %%
#there is 4.07% of towns with missing values
153/3756*100
# Out:
# 4.073482428115016

# %%
#here I am counting the number of hospitals in each Town
df1['Town'].value_counts()
# Out:
# Sunyani                                29
# Koforidua                              17
# Berekum                                16
# Ho                                     15
# Osu                                    15
# Techiman                               14
# Mampong                                14
# Adum                                   13
# Tema Community 1                       12
# Madina                                 11
# Winneba                                11
# Korle-Bu                               10
# Ashaiman                               10
# Nima                                    9
# Teshie                                  9
# Tema Community 2                        9
# Kasoa                                   9
# Bawku                                   9
# Asokwa                                  8
# Adabraka                                8
# Kintampo                                8
# Dzorwulu                                7
# ...

# %%
x = df1['Ownership']
y = df1['Ownership'].value_counts()

# %%
plt.rcParams['figure.figsize'] = 30, 10
plt.rcParams['font.size'] = 20.0 
df1['Ownership'].value_counts()[:10].plot(kind='bar')
plt.show()

# %%
# The histogram above represents number of hospitals owned by each catogory of owners.

# %%
df1 = df1.drop(df1.loc[df1['Town'].isnull()].index)

# %%
df1.isnull().sum().max()
# Out:
# 0

# %%
df1.shape
# Out:
# (3603, 6)

# %%
import plotly
from plotly import graph_objects as go

# %%
plt.rcParams['figure.figsize'] = 30, 10
plt.rcParams['font.size'] = 20.0 

df1['Region'].value_counts()[:10].plot(kind='bar')
plt.show()

# %%
# The plot above represents number of hspitals in each Region.
